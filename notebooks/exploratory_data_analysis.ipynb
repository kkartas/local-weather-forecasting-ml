# %% [markdown]
# # Exploratory Data Analysis
#
# Use this notebook for dissertation EDA after raw Weathercloud exports are available. Keep reusable preparation logic in MetDataPy and experiment orchestration in the package CLI.
